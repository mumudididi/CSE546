# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg
from tqdm import tqdm
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
def kernel_function_matrix(kernel_function, x,d):
    # input x should be a (n,) vector
    kernel_function2 = lambda x1,x2: kernel_function(x1,x2,d)
    n = x.shape[0]
    res = np.zeros((n,n),dtype = np.double)
    for i in range(n):
        for j in range(n):
            res[i,j] = kernel_function2(x[i],x[j])
    return res
    
def leave_one_out_CV(KSS, X,y, true_f,ds, lmbdas,kernel_func):
    lmbda_opt = None; d_opt = None; error_opt = 100000000;
    n = X.shape[0]
    for d in tqdm(ds) :
        for lmbda in lmbdas:
            KSS.lmbda = lmbda
            l2 = []
            for i in range(n):
                KSS.theta = None;
                KSS.prediction = None;
                X_cp = X[np.arange(n)!=i]
                y_cp = y[np.arange(n)!=i]
                K = kernel_function_matrix(kernel_func,X_cp,d)
                KSS.train(K,y_cp)
                KSS.predict(kernel_func,X[i],X_cp,d)
                l2.append(KSS.prediction)
            mse_error = 1/n * np.sum(np.power(true_f - np.array(l2),2))
            if (mse_error < error_opt) :
                error_opt = mse_error
                d_opt = d
                lmbda_opt = lmbda
    return lmbda_opt,d_opt,error_opt
                
def bootstrap(KRR,X,resample_size,y,kernel_func,d,B,lmbda):
    '''
    d is the hyperparameter 
    B is number of bootstraps
    KRR the kernel reg object
    
    return value : B-by-resample_size list/matrix
    '''
    KRR.lmbda = lmbda
    res = []
    for i in range(B):
        pred = []
        KRR.theta = None
        KRR.prediction = None
        selector = np.random.choice(30, 30,replace=True)
        X_selected = X[selector]
        y_selected = y[selector]
        K = kernel_function_matrix(kernel_func,X_selected,d)
        KRR.train(K,y_selected)
        for x in X: 
            KRR.predict(kernel_func,x,X_selected,d)
            pred.append(KRR.prediction)
        res.append(pred)
    return res

def k_fold_cross_validation(n,k,KRR,X,y, true_f,ds, lmbdas,kernel_func):
    subset_size = int(n/k)
    lmbda_opt = None; d_opt = None; error_opt = 100000000;
    for d in tqdm(ds):
        for lmbda in lmbdas: 
            KRR.theta = None
            KRR.prediction = None
            error=0
            for i in range(k): 
                start = int(i*subset_size) 
                end = int((i+1)*subset_size)
                X_cv = X[start:end]
                y_cv = y[start:end]
                X_cp = np.r_[X[0:start],X[end:]]
                y_cp = np.r_[y[0:start],y[end:]]
                true_f_cv = true_f[start:end]
                KRR.lmbda = lmbda
                
                ######## creating K #########
                K = kernel_function_matrix(kernel_func,X_cp,d)
                ####### training ########
                KRR.train(K,y_cp)
                temp_arr = np.zeros(subset_size)
                count = 0;
                for x_test in X_cv:
                    KRR.predict(kernel_func,x_test,X_cp,d)
                    temp_arr[count] = KRR.prediction
                    count += 1
                error += np.sum(np.power((temp_arr - true_f_cv),2)) 
            if error < error_opt:
                error_opt = error
                lmbda_opt = lmbda
                d_opt = d
            if error_opt/k <2: break
            
    return d_opt,lmbda_opt,error_opt/k

# %%
class KernelRedgeReg:
    def __init__(self, lmbda, theta = None):
        self.lmbda = lmbda
        self.theta = theta
        self.prediction = None
        
    def train(self,K, y):
        n = y.shape[0]
        
        self.theta = linalg.solve(K + self.lmbda * 
                                  np.eye(n,dtype = np.double), y)  # A\b
    
    def predict(self,kernel_func, test_x, train_x,d):
        kernel_func2 = lambda x1: kernel_func(x1,test_x,d)
        prediction = 0
        for a, x in zip(self.theta, train_x):
            prediction += a * kernel_func2(x)
        self.prediction = prediction

# %%
##########################################################
######### construct X f(X) y #############################
##########################################################
d = 30;n = 30

X =np.sort(np.random.uniform(0,1,30))
f = lambda x : 4 * np.sin(np.pi * x) * np.cos(6* np.pi * x**2)
y = f(X) + np.random.normal(0,1,30)

# %%
###########################################################
######## kernel function: exp(-d(x-z)**2)##################
###########################################################
#kernel_func = lambda x1,x2,d: (1 + x1*x2)**d
kernel_func_1 = lambda x1,x2,d: np.exp(-d*np.power((x1 - x2),2))
#K_1 = kernel_function_matrix(kernel_func,X,d)

################ init a new KRR obj #######################
KRR_1 = KernelRedgeReg(lmbda=None)

################ hyper-parameters #########################
ds_1 = np.arange(1,100,5)
lmbdas_1 = np.arange(0,.5,0.01)

################ fit LOOCV ################################
lmbda_opt_1,d_opt_1,error_opt_1 = leave_one_out_CV\
    (KRR_1, X, y, f(X),ds_1, lmbdas_1,kernel_func_1)
# Out:
# 100%|██████████| 20/20 [03:22<00:00, 10.12s/it]

# %%
##############################################################
############## A3 (a_1): kernel_func = exp(-d(x-z)**2)########
##############################################################

# %%
print("the optimal lambda value is {}".format(lmbda_opt_1))
print("the optimal d value is {}".format(d_opt_1))
print("the optimal error is {}".format(error_opt_1))
# Out:
# the optimal lambda value is 0.07
# the optimal d value is 96
# the optimal error is 0.1521915556100616

# %%
##############################################################
##### A3 (b_1):  kernel_func = exp(-d(x-z)**2)################
##############################################################

# %%
########## USING the optimal values to train the whole data set
KRR_1.lmbda = lmbda_opt_1
K_opt_1 = kernel_function_matrix(kernel_func_1,X,d_opt_1)
KRR.train(K_opt_1,y)
pred_list_1 =[]

########## predict the training set ###########################
for m in X: 
    KRR.predict(kernel_func_1,m,X,d_opt_1) 
    pred_list_1.append(KRR.prediction)

# %%
########### plot the training error ############################
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
plt.figure(figsize=(12,8)) 
plt.plot(X,y,"r.")
plt.plot(X,f(X),"y-")
plt.plot(X,pred_list_1,'m-')
plt.title('A3(b): function learned for rbf kernel exp(-d(x-z)**2))')
plt.legend(['true value + noise','true value','predicted'])

#plt.savefig('A3b_rbf')

# %%
###########################################################
######## kernel function: (1 +xx')^d ######################
###########################################################
kernel_func_2 = lambda x1,x2,d: (1 + x1*x2)**d

#K_2 = kernel_function_matrix(kernel_func_2,X,d)

################ init a new KRR obj #######################
KRR_2 = KernelRedgeReg(lmbda=None)

################ hyper-parameters #########################
ds_2 = np.arange(20,50,3)
lmbdas_2 =np.arange(0.001,.2,0.001)

################ fit LOOCV ################################
lmbda_opt_2,d_opt_2,error_opt_2 = leave_one_out_CV\
    (KRR_2, X, y, f(X),ds_2, lmbdas_2,kernel_func_2)
# Out:
# 100%|██████████| 10/10 [01:06<00:00,  6.61s/it]

# %%
##############################################################
############## A3 (a_2): kernel_func = (1 +xx')^d ############
##############################################################

# %%
print("the optimal lambda value is {}".format(lmbda_opt_2))
print("the optimal d value is {}".format(d_opt_2))
print("the optimal error is {}".format(error_opt_2))
# Out:
# the optimal lambda value is 0.137
# the optimal d value is 41
# the optimal error is 0.39018164835633473

# %%
##############################################################
##### A3 (b_2):  kernel_func = (1 +xx')^d   ##################
##############################################################

# %%
########## USING the optimal values to train the whole data set
KRR_2.lmbda = lmbda_opt_2
K_opt_2 = kernel_function_matrix(kernel_func_2,X,d_opt_2)
KRR_2.train(K_opt_2,y)
pred_list_2 =[]

########## predict the training set ###########################
for m in X: 
    KRR_2.predict(kernel_func_2,m,X,d_opt_2) 
    pred_list_2.append(KRR_2.prediction)

# %%
########### plot the training error ############################
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.axes_style("darkgrid")
plt.figure(figsize=(12,8)) 
plt.plot(X,y,"r.")
plt.plot(X,f(X),"y.-")
plt.plot(X,pred_list_2,'m-')
plt.title('A3(b): function learned for kernel poly kernel_func = (1 +x.Tz)^d')
plt.legend(['true value + noise','true value','predicted'])
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
#plt.savefig('A3b_poly')

# %%
##############################################################
###################### A3 (c) ################################
##############################################################

# %%
n_c = 30;B_c=300;d_c =d_opt_1; lmbda_c=lmbda_opt_1
resample_size =30
kernel_func_c = kernel_func_1
KRR_c = KernelRedgeReg(lmbda=None)

# %%
A3_c = bootstrap(KRR_c,X,resample_size,y,kernel_func_c,d_c,B_c,lmbda_c)

# %%
plt.figure(figsize=(12,8))
sns.set_style("darkgrid", {"axes.facecolor": ".2"})
for l in A3_c:
    plt.plot(X,l,'c.-',alpha = 0.4,linewidth=.5)
A3_arr = np.asarray(A3_c, dtype=np.double)
percentile_5 = np.percentile(A3_arr, q = 5, axis = 0)
percentile_95 = np.percentile(A3_arr, q = 95, axis = 0)
plt.plot(X, percentile_5 , 'r-v',alpha =1, linewidth = 2.5, label = '5 percentile')
plt.plot(X, percentile_95 , 'y-^',alpha = 1,linewidth = 2.5,label='95 percetile')

sns.set_style("darkgrid", {"axes.facecolor": ".6"})
plt.legend()
plt.title("bootstrap with 5% and 95% percentile")
#plt.plot(X_c,f(X_c),'k.-')
#plt.savefig('A3c_1')

# %%
plt.figure(figsize=(12,8)) 
sns.set_style("darkgrid", {"axes.facecolor": ".25"})
plt.plot(X, percentile_5 , 'r-v',alpha =1, linewidth = 2.5, label = '5 percentile')
plt.plot(X, percentile_95 , 'k-^',alpha = 1,linewidth = 2.5,label='95 percetile')
plt.plot(X,y,"g*", label = 'true + noise' )
plt.plot(X,f(X),"y:", label = 'true value',linewidth = 2.5)
plt.plot(X,pred_list_1,'m-',label = "predicted value")
sns.set_style("darkgrid", {"axes.facecolor": ".75"})
plt.legend()
plt.title("true values, predicted values vs. bootstrap 5 and 95 percentile ")
#plt.savefig('A3c_2')

# %%
percentile_5
# Out:
# (300,)

# %%
##############################################################
###################### A3 (c): kernel poly ###################
##############################################################

# %%
n_c = 30;B_c=300;d_c =d_opt_2; lmbda_c=lmbda_opt_2
resample_size =30
kernel_func_2 = lambda x1,x2,d: (1 + x1*x2)**d
kernel_func_c = kernel_func_2
KRR_c = KernelRedgeReg(lmbda=None)

# %%
lmbda_opt_2
# Out:
# 0.137

# %%
A3_c_2 = bootstrap(KRR_c,X,resample_size,y,kernel_func_c,d_c,B_c,lmbda_c)

# %%
plt.figure(figsize=(12,8))
sns.set_style("darkgrid", {"axes.facecolor": ".2"})
for l in A3_c_2:
    plt.plot(X,l,'c.-',alpha = 0.4,linewidth=.5)
plt.ylim([-6,6])
A3_arr_2 = np.asarray(A3_c_2, dtype=np.double)
percentile_5_2 = np.percentile(A3_arr_2, q = 5, axis = 0)
percentile_95_2 = np.percentile(A3_arr_2, q = 95, axis = 0)
plt.plot(X, percentile_5_2 , 'r-v',alpha =1, linewidth = 2.5, label = '5 percentile')
plt.plot(X, percentile_95_2 , 'y-^',alpha = 1,linewidth = 2.5,label='95 percetile')

sns.set_style("darkgrid", {"axes.facecolor": ".6"})
plt.legend()
plt.title("bootstrap with 5% and 95% percentile")
#plt.plot(X_c,f(X_c),'k.-')
#plt.savefig('A3c_poly1')
# Out:
# Text(0.5, 1.0, 'bootstrap with 5% and 95% percentile')

# %%
plt.figure(figsize=(12,8)) 
sns.set_style("darkgrid", {"axes.facecolor": ".25"})
plt.ylim([-6,6])
plt.plot(X, percentile_5_2 , 'r-v',alpha =1, linewidth = 2.5, label = '5 percentile')
plt.plot(X, percentile_95_2 , 'k-^',alpha = 1,linewidth = 2.5,label='95 percetile')
plt.plot(X,y,"g*", label = 'true + noise' )
plt.plot(X,f(X),"y:", label = 'true value',linewidth = 2.5)
plt.plot(X,pred_list_1,'m-',label = "predicted value")
sns.set_style("darkgrid", {"axes.facecolor": ".75"})
plt.legend()
plt.title("true values, predicted values vs. bootstrap 5 and 95 percentile ")
#plt.savefig('A3c_poly2')
# Out:
# Text(0.5, 1.0, 'true values, predicted values vs. bootstrap 5 and 95 percentile ')

# %%
##############################################################
###################### A3 (d): kernel poly ###################
##############################################################

# %%
##########################################################
######### construct X f(X) y #############################
##########################################################
n = 300

X =np.random.uniform(0,1,n)
f = lambda x : 4 * np.sin(np.pi * x) * np.cos(6* np.pi * x**2)
y = f(X) + np.random.normal(0,1,n)

ds = [.01,0.1,1,10,50,100,200,500]
lmbdas= np.arange(0,10,0.01)
k=10

# %%
KRR_d_rbf = KernelRedgeReg(lmbda =None)
d_opt_d_rbf,lmbda_opt_d_rbf,error_opt_d_rbf=k_fold_cross_validation(n,k,KRR_d_rbf,X,y, f(X),ds, lmbdas,kernel_func_1)
# Out:
# 100%|██████████| 8/8 [30:43<00:00, 230.40s/it]

# %%
print("the optimal lambda value is {}".format(lmbda_opt_d_rbf))
print("the optimal d value is {}".format(d_opt_d_rbf))
print("the optimal error is {}".format(errpr_opt_d_rbf))
# Out:
# the optimal lambda value is 1.2000000000000002
# the optimal d value is 200
# the optimal error is 2.3344538583606225

# %%
########## USING the optimal values to train the whole data set
KRR_d_rbf.lmbda = lmbda_opt_d_rbf
K_opt_d1 = kernel_function_matrix(kernel_func_1,X,d_opt_d_rbf)
KRR_d_rbf.train(K_opt_d1,y)
pred_list_d1 =[]

########## predict the training set ###########################
for m in X: 
    KRR_d_rbf.predict(kernel_func_1,m,X,d_opt_d_rbf) 
    pred_list_d1.append(KRR_d_rbf.prediction)

# %%
########### plot the training error ############################
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
plt.figure(figsize=(12,8)) 
plt.plot(X,y,"r.")
plt.plot(X,f(X),"y*")
plt.plot(X,pred_list_d1,'mv')
plt.title('A3(d): function learned for rbf kernel exp(-d(x-z)**2))')
plt.legend(['true value + noise','true value','predicted'])

plt.savefig('A3d_rbf')

# %%
n_d = 300;B_d=300;d_d =d_opt_d_rbf; lmbda_d=lmbda_opt_d_rbf
resample_size =300
kernel_func_d = kernel_func_1
KRR_d = KernelRedgeReg(lmbda=None)

# %%
A3_d = bootstrap(KRR_d,X,resample_size,y,kernel_func_d,d_d,B_d,lmbda_opt_d_rbf)

# %%
plt.figure(figsize=(12,8))
sns.set_style("darkgrid", {"axes.facecolor": ".2"})
for l in A3_d:
    plt.plot(X,l,'c.',alpha = 0.1,linewidth=.5)
A3_arr = np.asarray(A3_d, dtype=np.double)
percentile_5_d1 = np.percentile(A3_arr, q = 5, axis = 0)
percentile_95_d1 = np.percentile(A3_arr, q = 95, axis = 0)
plt.plot(X, percentile_5_d1 , 'rv',alpha =1, linewidth = 2.5, label = '5 percentile')
plt.plot(X, percentile_95_d1 , 'y^',alpha = 1,linewidth = 2.5,label='95 percetile')

sns.set_style("darkgrid", {"axes.facecolor": ".6"})
plt.legend()
plt.title("A3(d): bootstrap with 5% and 95% percentile with rbf kernel function")
#plt.plot(X_c,f(X_c),'k.-')
plt.savefig('A3d_rbf1')

# %%
plt.figure(figsize=(12,8)) 
sns.set_style("darkgrid", {"axes.facecolor": ".25"})
plt.plot(X, percentile_5_d1 , 'rv',alpha =1, linewidth = 2.5, label = '5 percentile')
plt.plot(X, percentile_95_d1 , 'y^',alpha = 1,linewidth = 2.5,label='95 percetile')
plt.plot(X,y,"g*", label = 'true + noise' )
plt.plot(X,f(X),"c+", label = 'true value',linewidth = 2.5)
plt.plot(X,pred_list_d1,'mx',label = "predicted value")
sns.set_style("darkgrid", {"axes.facecolor": ".75"})
plt.legend()
plt.title("true values, predicted values vs. bootstrap 5 and 95 percentile ")
plt.savefig('A3d_rbf2')

# %%
kernel_func_2 = lambda x1,x2,d: (1 + x1*x2)**d
KRR_d_poly = KernelRedgeReg(lmbda =None)
ds = np.arange(1,100,5)
lmbdas= np.arange(1,20,.5)
d_opt_d_poly,lmbda_opt_d_poly,error_opt_d_poly = k_fold_cross_validation(n,k,KRR_d_poly,X,y, f(X),ds, lmbdas,kernel_func_2)
# Out:
# 100%|██████████| 20/20 [11:59<00:00, 35.96s/it]

# %%
print("the optimal lambda value is {}".format(lmbda_opt_d_poly))
print("the optimal d value is {}".format(d_opt_d_poly))
print("the optimal error is {}".format(error_opt_d_poly))
# Out:
# the optimal lambda value is 1.0
# the optimal d value is 46
# the optimal error is 2.711868983841265

# %%
########## USING the optimal values to train the whole data set
KRR_d_poly.lmbda = lmbda_opt_d_poly
K_opt_d2 = kernel_function_matrix(kernel_func_2,X,d_opt_d_poly)
KRR_d_poly.train(K_opt_d2,y)
pred_list_d2 =[]

########## predict the training set ###########################
for m in X: 
    KRR_d_poly.predict(kernel_func_2,m,X,d_opt_d_poly) 
    pred_list_d2.append(KRR_d_poly.prediction)

# %%
########### plot the training error ############################
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
plt.figure(figsize=(12,8)) 
plt.plot(X,y,"r.")
plt.plot(X,f(X),"y*")
plt.plot(X,pred_list_d2,'mv')
plt.title('A3(d): function learned for poly kernel')
plt.legend(['true value + noise','true value','predicted'])

plt.savefig('A3d_poly')

# %%
n_d = 300;B_d=300;d_d =d_opt_d_poly; lmbda_d=lmbda_opt_d_poly
resample_size =300
kernel_func_d = kernel_func_2
KRR_d = KernelRedgeReg(lmbda=None)

# %%
A3_d_2 = bootstrap(KRR_d,X,resample_size,y,kernel_func_d,d_d,B_d,lmbda_d)

# %%
plt.figure(figsize=(12,8))
sns.set_style("darkgrid", {"axes.facecolor": ".2"})
plt.ylim([-10,10])
for l in A3_d_2:
    plt.plot(X,l,'c.',alpha = 0.1,linewidth=.5)
A3_arr = np.asarray(A3_d_2, dtype=np.double)
percentile_5_d2 = np.percentile(A3_arr, q = 5, axis = 0)
percentile_95_d2 = np.percentile(A3_arr, q = 95, axis = 0)
plt.plot(X, percentile_5_d2 , 'rv',alpha =1, linewidth = 2.5, label = '5 percentile')
plt.plot(X, percentile_95_d2 , 'y^',alpha = 1,linewidth = 2.5,label='95 percetile')

sns.set_style("darkgrid", {"axes.facecolor": ".6"})
plt.legend()
plt.title("A3(d): bootstrap with 5% and 95% percentile with poly kernel function")
#plt.plot(X_c,f(X_c),'k.-')
plt.savefig('A3d_poly1')

# %%
plt.figure(figsize=(12,8)) 
sns.set_style("darkgrid", {"axes.facecolor": ".2"})
plt.ylim([-10,10])

plt.plot(X, percentile_5_d2 , 'rv',alpha =1, linewidth = 2.5, label = '5 percentile')
plt.plot(X, percentile_95_d2 , 'y^',alpha = 1,linewidth = 2.5,label='95 percetile')
plt.plot(X,y,"g*", label = 'true + noise' )
plt.plot(X,f(X),"c+", label = 'true value',linewidth = 2.5)
plt.plot(X,pred_list_d2,'mx',label = "predicted value")
sns.set_style("darkgrid", {"axes.facecolor": ".75"})
plt.legend()
plt.title("true values, predicted values vs. bootstrap 5 and 95 percentile ")
plt.savefig('A3d_poly2')

# %%
import pickle

# %%
# # Saving the objects:
# with open('objs.pkl', 'wb') as f:  # Python 3: open(..., 'wb')
#     pickle.dump([X,y,d_opt_d_rbf,lmbda_opt_d_rbf,d_opt_d_poly,lmbda_opt_d_poly], f)

# %%
with open('objs.pkl','rb') as f:  # Python 3: open(..., 'rb')
    a,b,c,d,e,f = pickle.load(f)

# %%
# Out:
# array([0.60466367, 0.88378992, 0.97142139, 0.47945079, 0.31269668,
#        0.24146259, 0.4572662 , 0.85836336, 0.21229366, 0.5547022 ,
#        0.57608586, 0.46571582, 0.43502942, 0.82377403, 0.93746336,
#        0.93062449, 0.04671624, 0.97953158, 0.8566242 , 0.31960075,
#        0.51566656, 0.79167529, 0.3161903 , 0.99528114, 0.28864867,
#        0.69997496, 0.39686188, 0.10999363, 0.69855589, 0.57701652,
#        0.61650598, 0.20398558, 0.63162635, 0.35038595, 0.76671523,
#        0.02390174, 0.36849966, 0.95103011, 0.89643652, 0.13897263,
#        0.06389379, 0.00545336, 0.26854554, 0.02446603, 0.83224501,
#        0.41209021, 0.38946442, 0.47475673, 0.74547912, 0.69413647,
#        0.10618437, 0.47622529, 0.26989441, 0.1501912 , 0.10818073,
#        0.60567009, 0.50589575, 0.68316123, 0.99785572, 0.31030446,
#        0.48273551, 0.09410524, 0.68268925, 0.41768466, 0.09499554,
#        0.87038829, 0.48831836, 0.2945351 , 0.12044202, 0.09358739,
#        0.29768665, 0.71259345, 0.18567681, 0.03978918, 0.12322414,
#        0.49862089, 0.41822504, 0.50285264, 0.23652866, 0.55979691,
#        0.94434065, 0.99692315, 0.73963794, 0.62723415, 0.97110729,
#        0.45396544, 0.72943146, 0.14444791, 0.24024455, 0.25139852,
#        0.36060181, 0.20009013, 0.7888478 , 0.24296733, 0.62789501,
#        0.66646011, 0.87431049, 0.83579429, 0.88920664, 0.86276383,
#        0.82445377, 0.79603908, 0.19652316, 0.2026872 , 0.89959965,
#        0.46233795, 0.51224695, 0.6381387 , 0.63435782, 0.91655084,
#        0.37697513, 0.68447355, 0.26241364, 0.40459533, 0.82216638,
#        0.39938363, 0.21597253, 0.90013219, 0.46739327, 0.36191702,
#        0.71238845, 0.36989475, 0.16288068, 0.99941335, 0.90993214,
#        0.05728444, 0.85433424, 0.37692255, 0.50780454, 0.79238315,
#        0.2268191 , 0.33910373, 0.95730623, 0.03844793, 0.50959848,
#        0.8650562 , 0.27549323, 0.79296626, 0.45584153, 0.44633711,
#        0.62604822, 0.14947497, 0.11153306, 0.92072507, 0.32910817,
#        0.5074408 , 0.53783064, 0.35535963, 0.21094809, 0.42392623,
#        0.78949213, 0.34895716, 0.99454797, 0.07408852, 0.29710643,
#        0.00432636, 0.79678739, 0.19664353, 0.50810985, 0.12163761,
#        0.16116829, 0.17267588, 0.54907859, 0.50479736, 0.43638605,
#        0.58464034, 0.03039663, 0.80946814, 0.94345986, 0.72349948,
#        0.00619686, 0.5243288 , 0.07895265, 0.1028452 , 0.16802153,
#        0.41166914, 0.44271041, 0.53616129, 0.6756185 , 0.49587056,
#        0.45127641, 0.69601657, 0.11677151, 0.69244596, 0.6775306 ,
#        0.50049072, 0.79618035, 0.49250014, 0.0851962 , 0.94529256,
#        0.45900484, 0.0092493 , 0.83007355, 0.61456482, 0.40874186,
#        0.24809083, 0.3974326 , 0.38396244, 0.81525146, 0.2359607 ,
#        0.91100165, 0.35428186, 0.40730948, 0.18623439, 0.50423327,
#        0.77435024, 0.18156701, 0.85125608, 0.71211863, 0.66908391,
#        0.47322015, 0.18872131, 0.84829468, 0.43321824, 0.87311871,
#        0.59363349, 0.25859828, 0.23341789, 0.85510254, 0.66405395,
#        0.50550538, 0.25445577, 0.83668099, 0.65651842, 0.7638283 ,
#        0.29985984, 0.03429755, 0.11899929, 0.67224892, 0.59372986,
#        0.6288503 , 0.39154147, 0.629141  , 0.39051207, 0.11745397,
#        0.34236534, 0.92285557, 0.95759053, 0.36347133, 0.88960482,
#        0.52683925, 0.64229732, 0.6128921 , 0.67331092, 0.48703501,
#        0.39975811, 0.58811784, 0.17675649, 0.34177171, 0.61768873,
#        0.30224973, 0.2677427 , 0.06275645, 0.3578592 , 0.14955634,
#        0.77785953, 0.55973027, 0.54742837, 0.09629932, 0.9789443 ,
#        0.97713363, 0.80211354, 0.42073696, 0.49166582, 0.34174209,
#        0.77962848, 0.26252445, 0.65995445, 0.93403539, 0.58548461,
#        0.15956092, 0.59053596, 0.60472015, 0.72789127, 0.0999179 ,
#        0.36103227, 0.1068981 , 0.07454878, 0.95034241, 0.20646488,
#        0.56559905, 0.29106302, 0.55409088, 0.94504335, 0.3424419 ,
#        0.31448074, 0.55887726, 0.15908222, 0.33994833, 0.19178637,
#        0.43190804, 0.07859422, 0.24439798, 0.78536027, 0.93785497,
#        0.15121913, 0.78743256, 0.08674637, 0.1894071 , 0.31648606])
